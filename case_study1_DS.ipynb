# %% [markdown]
# <a href="https://colab.research.google.com/github/Soumiyads2004/FODS_54/blob/main/case_study1_DS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
dd=pd.read_excel('payroll_dataset.xlsx',sheet_name='Departments')
de=pd.read_excel('payroll_dataset.xlsx',sheet_name='Employees')

# %%
merged_tab=pd.merge(de,dd,on='DepartmentID')
merged_tab.head(5)
# Out:
#    EmployeeID         Name DepartmentID  Salary    HireDate  Location  \
# 0           1   Employee 1         D001    6000  2020-01-31  New York
# 1           5   Employee 5         D001    6400  2020-05-31  New York
# 2           9   Employee 9         D001    6800  2020-09-30  New York
# 3          13  Employee 13         D001    7200  2021-01-31  New York
# 4          17  Employee 17         D001    7600  2021-05-31  New York
#
#   DepartmentName
# 0             IT
# 1             IT
# 2             IT
# 3             IT
# 4             IT

# %%
merged_tab.drop_duplicates()
merged_tab.head(5)
# Out:
#    EmployeeID         Name DepartmentID  Salary    HireDate  Location  \
# 0           1   Employee 1         D001    6000  2020-01-31  New York
# 1           5   Employee 5         D001    6400  2020-05-31  New York
# 2           9   Employee 9         D001    6800  2020-09-30  New York
# 3          13  Employee 13         D001    7200  2021-01-31  New York
# 4          17  Employee 17         D001    7600  2021-05-31  New York
#
#   DepartmentName
# 0             IT
# 1             IT
# 2             IT
# 3             IT
# 4             IT

# %%
q1=merged_tab['Salary'].quantile(0.75)
q3=merged_tab['Salary'].quantile(0.25)

# %%
iqr=q3-q1
lb=q1-1.5*iqr
ub=q3+1.5*iqr

# %%
outlier=(merged_tab[['Salary']]<lb)|( merged_tab[['Salary']]>ub)
outlier
# Out:
#     Salary
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# ..     ...
# 95    True
# 96    True
# 97    True
# 98    True
# 99    True
#
# [100 rows x 1 columns]

# %%
clean=(~merged_tab.isin(outlier))
clean
# Out:
#     EmployeeID  Name  DepartmentID  Salary  HireDate  Location  DepartmentName
# 0         True  True          True    True      True      True            True
# 1         True  True          True    True      True      True            True
# 2         True  True          True    True      True      True            True
# 3         True  True          True    True      True      True            True
# 4         True  True          True    True      True      True            True
# ..         ...   ...           ...     ...       ...       ...             ...
# 95        True  True          True    True      True      True            True
# 96        True  True          True    True      True      True            True
# 97        True  True          True    True      True      True            True
# 98        True  True          True    True      True      True            True
# 99        True  True          True    True      True      True            True
#
# [100 rows x 7 columns]

# %%
sal_min=merged_tab['Salary'].min()
sal_max=merged_tab['Salary'].max()

# %%
merged_tab['Salary']=(merged_tab['Salary']-sal_min)/(sal_max-sal_min)
merged_tab
# Out:
#     EmployeeID          Name DepartmentID    Salary    HireDate  Location  \
# 0            1    Employee 1         D001  0.000000  2020-01-31  New York
# 1            5    Employee 5         D001  0.040404  2020-05-31  New York
# 2            9    Employee 9         D001  0.080808  2020-09-30  New York
# 3           13   Employee 13         D001  0.121212  2021-01-31  New York
# 4           17   Employee 17         D001  0.161616  2021-05-31  New York
# ..         ...           ...          ...       ...         ...       ...
# 95          84   Employee 84         D004  0.838384  2026-12-31   Houston
# 96          88   Employee 88         D004  0.878788  2027-04-30   Houston
# 97          92   Employee 92         D004  0.919192  2027-08-31   Houston
# 98          96   Employee 96         D004  0.959596  2027-12-31   Houston
# 99         100  Employee 100         D004  1.000000  2028-04-30   Houston
#
#    DepartmentName
# 0              IT
# 1              IT
# 2              IT
# 3              IT
# 4              IT
# ..            ...
# 95      Marketing
# 96      Marketing
# 97      Marketing
# 98      Marketing
# 99      Marketing
#
# [100 rows x 7 columns]

# %%
dummies=pd.get_dummies(merged_tab,columns=['Location'])
dummies
# Out:
#     EmployeeID          Name DepartmentID    Salary    HireDate  \
# 0            1    Employee 1         D001  0.000000  2020-01-31
# 1            5    Employee 5         D001  0.040404  2020-05-31
# 2            9    Employee 9         D001  0.080808  2020-09-30
# 3           13   Employee 13         D001  0.121212  2021-01-31
# 4           17   Employee 17         D001  0.161616  2021-05-31
# ..         ...           ...          ...       ...         ...
# 95          84   Employee 84         D004  0.838384  2026-12-31
# 96          88   Employee 88         D004  0.878788  2027-04-30
# 97          92   Employee 92         D004  0.919192  2027-08-31
# 98          96   Employee 96         D004  0.959596  2027-12-31
# 99         100  Employee 100         D004  1.000000  2028-04-30
#
#    DepartmentName  Location_Chicago  Location_Houston  Location_Los Angeles  \
# 0              IT             False             False                 False
# 1              IT             False             False                 False
# 2              IT             False             False                 False
# 3              IT             False             False                 False
# 4              IT             False             False                 False
# ..            ...               ...               ...                   ...
# 95      Marketing             False              True                 False
# 96      Marketing             False              True                 False
# 97      Marketing             False              True                 False
# 98      Marketing             False              True                 False
# 99      Marketing             False              True                 False
#
#     Location_New York
# 0                True
# 1                True
# 2                True
# 3                True
# 4                True
# ..                ...
# 95              False
# 96              False
# 97              False
# 98              False
# 99              False
#
# [100 rows x 10 columns]

# %%
dummies=pd.get_dummies(merged_tab,columns=['Location'],drop_first=False)
dummies
# Out:
#     EmployeeID          Name DepartmentID    Salary    HireDate  \
# 0            1    Employee 1         D001  0.000000  2020-01-31
# 1            5    Employee 5         D001  0.040404  2020-05-31
# 2            9    Employee 9         D001  0.080808  2020-09-30
# 3           13   Employee 13         D001  0.121212  2021-01-31
# 4           17   Employee 17         D001  0.161616  2021-05-31
# ..         ...           ...          ...       ...         ...
# 95          84   Employee 84         D004  0.838384  2026-12-31
# 96          88   Employee 88         D004  0.878788  2027-04-30
# 97          92   Employee 92         D004  0.919192  2027-08-31
# 98          96   Employee 96         D004  0.959596  2027-12-31
# 99         100  Employee 100         D004  1.000000  2028-04-30
#
#    DepartmentName  Location_Chicago  Location_Houston  Location_Los Angeles  \
# 0              IT             False             False                 False
# 1              IT             False             False                 False
# 2              IT             False             False                 False
# 3              IT             False             False                 False
# 4              IT             False             False                 False
# ..            ...               ...               ...                   ...
# 95      Marketing             False              True                 False
# 96      Marketing             False              True                 False
# 97      Marketing             False              True                 False
# 98      Marketing             False              True                 False
# 99      Marketing             False              True                 False
#
#     Location_New York
# 0                True
# 1                True
# 2                True
# 3                True
# 4                True
# ..                ...
# 95              False
# 96              False
# 97              False
# 98              False
# 99              False
#
# [100 rows x 10 columns]
